# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %%
corona_death_dataset_csv = pd.read_csv("covid19_deaths_dataset.csv")
corona_death_dataset_csv.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_death_dataset_csv.shape
# Out:
# (266, 104)

# %%
corona_death_dataset_csv.drop(["Lat", "Long"], axis=1, inplace=True)

# %%
corona_death_dataset_csv.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_death_aggregated = corona_death_dataset_csv.groupby("Country/Region").sum()

# %%
corona_death_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       36       40       42
# Albania               0        0        0  ...       26       27       27
# Algeria               0        0        0  ...      392      402      407
# Andorra               0        0        0  ...       37       37       37
# ...

# %%
corona_death_aggregated.shape
# Out:
# (187, 100)

# %%
corona_death_aggregated.loc["China"].plot()
corona_death_aggregated.loc["India"].plot()
corona_death_aggregated.loc["France"].plot()
plt.legend()

# %%
corona_death_aggregated.loc["China"][:3].plot()
# Out:
# <AxesSubplot:>

# %%
corona_death_aggregated.loc["China"].diff().plot()
# Out:
# <AxesSubplot:>

# %%
corona_death_aggregated.loc["China"].diff().max()
# Out:
# 1290.0

# %%
corona_death_aggregated.loc["India"].diff().max()
# Out:
# 75.0

# %%
corona_death_aggregated.loc["France"].diff().max()
# Out:
# 1440.0

# %%
countries = list(corona_death_aggregated.index)
max_death_rates = []
for c in countries:
    max_death_rates.append(corona_death_aggregated.loc[c].diff().max())
corona_death_aggregated["max_death_rates"] = max_death_rates

# %%
corona_death_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %%
corona_data = pd.DataFrame(corona_death_aggregated["max_death_rates"])
corona_data.head()
# Out:
#                 max_death_rates
# Country/Region
# Afghanistan                 7.0
# Albania                     4.0
# Algeria                    30.0
# Andorra                     4.0
# Angola                      2.0

# %%
happiness_report_csv = pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
happiness_report_csv.drop(["Overall rank", "Score", "Generosity", "Perceptions of corruption"], axis=1, inplace=True)

# %%
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report_csv.set_index("Country or region", inplace=True)
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
corona_data.head()
# Out:
#                 max_death_rates
# Country/Region
# Afghanistan                 7.0
# Albania                     4.0
# Algeria                    30.0
# Andorra                     4.0
# Angola                      2.0

# %%
data = corona_data.join(happiness_report_csv,how = "inner")
data.head()
# Out:
#              max_death_rates  GDP per capita  Social support  \
# Afghanistan              7.0           0.350           0.517
# Albania                  4.0           0.947           0.848
# Algeria                 30.0           1.002           1.160
# Argentina               13.0           1.092           1.432
# Armenia                  3.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
data.corr()
# Out:
#                               max_death_rates  GDP per capita  Social support  \
# max_death_rates                      1.000000        0.259893        0.204148
# GDP per capita                       0.259893        1.000000        0.759468
# Social support                       0.204148        0.759468        1.000000
# Healthy life expectancy              0.309666        0.863062        0.765286
# Freedom to make life choices         0.080166        0.394603        0.456246
#
#                               Healthy life expectancy  \
# max_death_rates                              0.309666
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# max_death_rates                                   0.080166
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#              max_death_rates  GDP per capita  Social support  \
# Afghanistan              7.0           0.350           0.517
# Albania                  4.0           0.947           0.848
# Algeria                 30.0           1.002           1.160
# Argentina               13.0           1.092           1.432
# Armenia                  3.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
x=data["GDP per capita"]
y=data["max_death_rates"]
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\subhr\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\subhr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_death_rates'>

# %%
x=data["Social support"]
y=data["max_death_rates"]
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\subhr\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\subhr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='max_death_rates'>

# %%
x=data["Healthy life expectancy"]
y=data["max_death_rates"]
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\subhr\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\subhr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_death_rates'>

# %%
x=data["Freedom to make life choices"]
y=data["max_death_rates"]
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\subhr\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\subhr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_death_rates'>
